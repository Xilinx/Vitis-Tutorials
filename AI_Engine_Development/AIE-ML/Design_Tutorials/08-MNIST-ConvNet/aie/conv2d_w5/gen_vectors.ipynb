# %% [markdown]
# # Testbench for `conv2d_w5()`

# %%
#
# Copyright (C) 2024, Advanced Micro Devices, Inc. All rights reserved.
# SPDX-License-Identifier: MIT
#
# Author: Mark Rollins

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from tensorflow.keras import mixed_precision
import numpy as np
import os.path
import os as os
import vfs
import varray as va
import re
# Out:
# 2025-03-15 14:41:04.071766: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-15 14:41:04.078040: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-15 14:41:04.089240: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742071264.104513 3769680 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742071264.109189 3769680 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-15 14:41:04.131248: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Layer Definition

# %%
inputs = keras.Input(shape=(28,28,1),name="input")
x1 = layers.Conv2D(filters=16,kernel_size=3,activation="relu",name="conv2d_w1")(inputs)
x2 = layers.MaxPooling2D(pool_size=2,name="max_pooling2d_w2")(x1)
x3 = layers.Conv2D(filters=64,kernel_size=3,activation="relu",name="conv2d_w3")(x2)
outputs = layers.MaxPooling2D(pool_size=2,name="max_pooling2d_w4")(x3)
model_stim = keras.Model(inputs=inputs,outputs=outputs,name="Stimulus")
w1_taps = np.loadtxt('../conv2d_w1/taps_trained.txt')
w1_taps = np.reshape(w1_taps,(3,3,1,16))
w1_taps = (w1_taps.astype("bfloat16")).astype("float32")
w1_bias = np.loadtxt('../conv2d_w1/bias_trained.txt')
w1_bias = (w1_bias.astype("bfloat16")).astype("float32")
w3_taps = np.loadtxt('../conv2d_w3/taps_trained.txt')
w3_taps = np.reshape(w3_taps,(3,3,16,64))
w3_taps = (w3_taps.astype("bfloat16")).astype("float32")
w3_bias = np.loadtxt('../conv2d_w3/bias_trained.txt')
w3_bias = (w3_bias.astype("bfloat16")).astype("float32")
model_stim.set_weights((w1_taps,w1_bias,w3_taps,w3_bias))
# Out:
# 2025-03-15 14:41:07.343668: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model_stim.summary()
# Out:
# Model: "Stimulus"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_w1 (Conv2D)              │ (None, 26, 26, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_w2 (MaxPooling2D) │ (None, 13, 13, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_w3 (Conv2D)              │ (None, 11, 11, 64)     │         9,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_w4 (MaxPooling2D) │ (None, 5, 5, 64)       │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,440 (36.88 KB)
#  Trainable params: 9,440 (36.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
inputs = keras.Input(shape=(5,5,64),name="input_layer")
outputs = layers.Conv2D(filters=128,kernel_size=3,activation="relu",name="conv2d_w5")(inputs)
model = keras.Model(inputs=inputs,outputs=outputs,name="dut")
w5_taps = np.loadtxt('taps_trained.txt')
w5_taps = np.reshape(w5_taps,(3,3,64,128))
w5_taps = (w5_taps.astype("bfloat16")).astype("float32")
w5_bias = np.loadtxt('bias_trained.txt')
w5_bias = (w5_bias.astype("bfloat16")).astype("float32")
model.set_weights((w5_taps,w5_bias))

# %%
model.summary()
# Out:
# Model: "dut"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_w5 (Conv2D)              │ (None, 3, 3, 128)      │        73,856 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,856 (288.50 KB)
#  Trainable params: 73,856 (288.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Load NMIST Images

# %%
# Set batch size and # of batches
BS=1
NB_tst = 4
# Load MNIST database:
(trn_images,trn_labels), (tst_images,tst_labels) = mnist.load_data()
tst_images = tst_images.reshape((10000,28,28,1))
tst_images = tst_images[:NB_tst*BS,:,:,:]
# Extract usable data:
tst_labels = tst_labels[:NB_tst*BS]
tst_images = tst_images.astype("float32") / 255
tst_inputs = model_stim.predict(tst_images,batch_size=1)
tst_inputs = (tst_inputs.astype("bfloat16")).astype("float32")
use_inputs = np.zeros((4,5,8,64),dtype="float32");
use_inputs[:,:,0:5,:] = tst_inputs
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ## Compute Golden Outputs

# %%
predict = model.predict(tst_inputs.astype("float32"),batch_size=1)
predict = (predict.astype("bfloat16")).astype("float32")
fig,ax = plt.subplots(nrows=1,ncols=1)
ax.imshow(tst_inputs[0,:,:,0],cmap=plt.cm.binary)
fig,ax = plt.subplots(nrows=4,ncols=4)
for ii in range(4):
    for jj in range(4):
        ax[ii,jj].imshow(predict[0,:,:,4*ii+jj],cmap=plt.cm.binary)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## Store Layer Inputs

# %%
os.makedirs('data',exist_ok=True)
print(use_inputs.shape)
np.savetxt('data/ifm_i.txt',np.reshape(use_inputs,(-1,4)),fmt='%f %f %f %f')
ifm_i = np.reshape(use_inputs,(-1,1))
# Out:
# (4, 5, 8, 64)

# %% [markdown]
# ## Store Layer Outputs

# %%
print(predict.shape)
np.savetxt('data/ofm_o.txt',np.reshape(predict,(-1,4)),fmt='%f %f %f %f')
ofm_o = np.reshape(predict,(-1,1))
# Out:
# (4, 3, 3, 128)

# %% [markdown]
# ## Store Weights & Bias

# %%
print(w5_taps.shape)
taps = np.reshape(w5_taps,(3,3,8,8,32,4))
taps = np.transpose(taps,(4,2,0,1,3,5))
taps0 = np.concatenate((np.reshape(taps[ 0: 8,:,:,:,:,:],(-1,1)),np.reshape(w5_bias[ 0: 32],(-1,1))),axis=0);
taps1 = np.concatenate((np.reshape(taps[ 8:16,:,:,:,:,:],(-1,1)),np.reshape(w5_bias[32: 64],(-1,1))),axis=0);
taps2 = np.concatenate((np.reshape(taps[16:24,:,:,:,:,:],(-1,1)),np.reshape(w5_bias[64: 96],(-1,1))),axis=0);
taps3 = np.concatenate((np.reshape(taps[24:32,:,:,:,:,:],(-1,1)),np.reshape(w5_bias[96:128],(-1,1))),axis=0);
np.savetxt('data/wts_0_i.txt',np.reshape(taps0,(-1,4)),fmt='%f %f %f %f')
np.savetxt('data/wts_1_i.txt',np.reshape(taps1,(-1,4)),fmt='%f %f %f %f')
np.savetxt('data/wts_2_i.txt',np.reshape(taps2,(-1,4)),fmt='%f %f %f %f')
np.savetxt('data/wts_3_i.txt',np.reshape(taps3,(-1,4)),fmt='%f %f %f %f')
wts_0_i = np.reshape(taps0,(-1,1))
wts_1_i = np.reshape(taps1,(-1,1))
wts_2_i = np.reshape(taps2,(-1,1))
wts_3_i = np.reshape(taps3,(-1,1))
# Out:
# (3, 3, 64, 128)

# %% [markdown]
# ## Run Vitis Functional Simulation

# %%
conv2d_w5_graph = vfs.aieGraph(
    input_file='conv2d_w5_app.cpp',
    part="xcve2802-vsvh1760-2MP-e-S",
    include_paths=['./','../mnist','../wts_init'])
act_o = conv2d_w5_graph.run(va.array(ifm_i[:,0],va.bfloat16),
                            va.array(wts_0_i[:,0],va.bfloat16),
                            va.array(wts_1_i[:,0],va.bfloat16),
                            va.array(wts_2_i[:,0],va.bfloat16),
                            va.array(wts_3_i[:,0],va.bfloat16))
# Out:
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/bin/v++
# Compiling AIE Graph
# Compilation directory: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7
# Compilation command: v++ -c --mode aie --config vfs_work/conv2d_w5_app_c8052cf7/conv2d_w5_app.cfg --work_dir vfs_work/conv2d_w5_app_c8052cf7/Work --output vfs_work/conv2d_w5_app_c8052cf7/libadf.a --target x86sim
#
#
# ****** v++ v2025.1.0 (64-bit)
#   **** SW Build 6062557 on 2025-03-09-09:18:44
#   **** Start of session at: Sat Mar 15 14:41:10 2025
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
#
# INFO: [v++ 60-1548] Creating build summary session with primary output /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/Work.aiecompiler_summary, at Sat Mar 15 14:41:12 2025
# INFO: [v++ 82-31] Launching aiecompiler: aiecompiler --config /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/aie_x86sim.cfg
#                                            AI Engine Compiler
#                                      Version 2025.1.0 (linux64-bit)
#                                      SW Build 6062694 on 2025-03-09-13:51:25
#                           Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#                           Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
# INFO: ML part stats configuration file found in /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data
# INFO: [aiecompiler 77-297] Cmd Line : /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/bin/unwrapped/lnx64.o/aiecompiler --config /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/aie_x86sim.cfg
# INFO: [aiecompiler 77-404] Executing Cmd: /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/bin/../lnx64.o/tools/clang/bin/clang++ -I/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include -I/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/gcc/include/c++/8.3.0 -I/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/gcc/include/c++/8.3.0/x86_64-pc-linux-gnu -I/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/gcc/include  -Wno-error=reserved-user-defined-literal  -E -std=c++17 -D__ADF_FRONTEND__ -D__AIE_ARCH__=20 -I/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include  -I .  -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/conv2d_w5_app.cpp > /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app.ii
# INFO: [aiecompiler 77-404] Executing Cmd: graph_preprocessor /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app.ii -o /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app.processed.ii -report-core-dump  -- -std=c++17  -ftemplate-depth=2048  -Wno-return-stack-address  -Wno-missing-declarations  -Wno-parentheses-equality  -Wno-shift-negative-value
# INFO: [aiecompiler 77-404] Executing Cmd: /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/bin/../lnx64.o/tools/clang/bin/clang++ --ld-path=/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/binutils-2.42/bin/ld --gcc-install-dir=/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/gcc/lib/gcc/x86_64-pc-linux-gnu/8.3.0 -stdlib=libstdc++  -Wno-error=reserved-user-defined-literal  -std=c++17  -I .  /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app.processed.ii -o /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app.out -L /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/lib/lnx64.o -g -O0 -Wl,--unresolved-symbols=ignore-all  -Wno-return-stack-address  -Wno-missing-declarations  -lmeir_frontend  -ladf_api_frontend
# INFO: [aiecompiler 77-404] Executing Cmd: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app.out -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init --workdir=/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work --part=xcve2802-vsvh1760-2MP-e-S --aiearch=aie-ml --log-level=1 --pl-axi-lite=0 --enable-multi-layer=0 --multi-layer-opt=0 --disable-dma-autostart=0 --enable-light-cdo=0 --large-program-memory=0 --swfifo-threshold=40 --enable-dma-fifo=1 --target=x86sim
# INFO: [aiecompiler 77-749] Reading logical device VC2802.json
# INFO: [aiecompiler 77-6447] Executing Cmd: aieir_be --time-passes=0  --workdir=/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work  --target=x86sim --include="/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./" --include="/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist" --include="/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init" --output-archive=vfs_work/conv2d_w5_app_c8052cf7/libadf.a  --event-trace-port=gmio --part=xcve2802-vsvh1760-2MP-e-S  --json="/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app.json"
# INFO: [aiecompiler 77-749] Reading logical device VC2802.json
# 689: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app.json
# INFO: [aiecompiler 77-757] Opening input file: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app.json
# INFO: [aiecompiler 77-6287] Emitting AIEIr in file: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/temp/conv2d_w5_app_aieir_dump.txt
# INFO: [aiecompiler 77-656] Processing Graph 'root'
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.kkD is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.kkA is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.weights[3].kk is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.kkB is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.MT0 is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.kkC is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.weights[1].kk is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.MT1 is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.weights[2].kk is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.weights[0].kk is 4.
# INFO: [aiecompiler 77-5607] ### Entering X86Sim Switch Configuration pass
# INFO: [aiecompiler 77-5606] ### Done with X86Sim Switch Configuration pass
# DEBUG:Buildx86simCFGraph:### Entering Build CFGraph pass
# DEBUG:Buildx86simCFGraph:### CF Graph is built
# INFO: [aiecompiler 77-610] Performing x86Sim Graph Analysis
# Start processing Node Instances.
# Processing Node Instance: me  i0:b0 runtime:0.8999 {
#    portinst: i0_pi0 idx[0] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  kk.in[0])
#    portinst: i0_po0 idx[1] datatype:buff<bfloat16> mem out bw_utlization = 1 synctype:async (variable name:  kk.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: me  i1:b0 runtime:0.8999 {
#    portinst: i1_pi0 idx[0] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  kk.in[0])
#    portinst: i1_po0 idx[1] datatype:buff<bfloat16> mem out bw_utlization = 1 synctype:async (variable name:  kk.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: me  i2:b0 runtime:0.8999 {
#    portinst: i2_pi0 idx[0] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  kk.in[0])
#    portinst: i2_po0 idx[1] datatype:buff<bfloat16> mem out bw_utlization = 1 synctype:async (variable name:  kk.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: me  i3:b0 runtime:0.8999 {
#    portinst: i3_pi0 idx[0] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  kk.in[0])
#    portinst: i3_po0 idx[1] datatype:buff<bfloat16> mem out bw_utlization = 1 synctype:async (variable name:  kk.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: me  i4:b1 runtime:0.8999 {
#    portinst: i4_pi0 idx[0] datatype:buff<bfloat16> mem in bw_utlization = 1 (variable name:  kkA.in[0])
#    portinst: i4_pi1 idx[1] datatype:buff<bfloat16> mem in bw_utlization = 1 synctype:async (variable name:  kkA.in[1])
#    portinst: i4_po0 idx[2] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  kkA.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: me  i5:b2 runtime:0.8999 {
#    portinst: i5_pi0 idx[0] datatype:buff<bfloat16> mem in bw_utlization = 1 (variable name:  kkB.in[0])
#    portinst: i5_pi1 idx[1] datatype:buff<bfloat16> mem in bw_utlization = 1 synctype:async (variable name:  kkB.in[1])
#    portinst: i5_pi2 idx[2] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  kkB.in[2])
#    portinst: i5_po0 idx[3] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  kkB.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: me  i6:b3 runtime:0.8999 {
#    portinst: i6_pi0 idx[0] datatype:buff<bfloat16> mem in bw_utlization = 1 (variable name:  kkC.in[0])
#    portinst: i6_pi1 idx[1] datatype:buff<bfloat16> mem in bw_utlization = 1 synctype:async (variable name:  kkC.in[1])
#    portinst: i6_pi2 idx[2] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  kkC.in[2])
#    portinst: i6_po0 idx[3] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  kkC.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: me  i7:b4 runtime:0.8999 {
#    portinst: i7_pi0 idx[0] datatype:buff<bfloat16> mem in bw_utlization = 1 (variable name:  kkD.in[0])
#    portinst: i7_pi1 idx[1] datatype:buff<bfloat16> mem in bw_utlization = 1 synctype:async (variable name:  kkD.in[1])
#    portinst: i7_pi2 idx[2] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  kkD.in[2])
#    portinst: i7_po0 idx[3] datatype:buff<bfloat16> mem out bw_utlization = 1 (variable name:  kkD.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: SharedBuffer  i8:b5 { dimensions: (2560 ) elemType:bfloat16 numBuffers:1
#    portinst: i8_pi0 idx[0] datatype:bfloat16 dma in bw_utlization = 1 (variable name:  MT0.in[0])
#    portinst: i8_po0 idx[1] datatype:bfloat16 dma out bw_utlization = 1 (variable name:  MT0.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: SharedBuffer  i9:b6 { dimensions: (3072 ) elemType:bfloat16 numBuffers:1
#    portinst: i9_pi0 idx[0] datatype:bfloat16 dma in bw_utlization = 1 (variable name:  MT1.in[0])
#    portinst: i9_po0 idx[1] datatype:bfloat16 dma out bw_utlization = 1 (variable name:  MT1.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: plio  nodeinst:i10:b7 {
#    portinst: i10_po0 idx[-1] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  ifm_i.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: plio  nodeinst:i11:b8 {
#    portinst: i11_po0 idx[-1] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  wts_i[0].out[0])
# }
# Node Instance processing done.
# Processing Node Instance: plio  nodeinst:i12:b9 {
#    portinst: i12_po0 idx[-1] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  wts_i[1].out[0])
# }
# Node Instance processing done.
# Processing Node Instance: plio  nodeinst:i13:b10 {
#    portinst: i13_po0 idx[-1] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  wts_i[2].out[0])
# }
# Node Instance processing done.
# Processing Node Instance: plio  nodeinst:i14:b11 {
#    portinst: i14_po0 idx[-1] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  wts_i[3].out[0])
# }
# Node Instance processing done.
# Processing Node Instance: plio  nodeinst:i15:b12 {
#    portinst: i15_pi0 idx[-1] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  ofm_o.in[0])
# }
# Node Instance processing done.
# Finished processing Node Instances.
# Processing: Channel net0: Single :src:i11_po0 dst:i0_pi0
# Processing: Channel net1: Single :src:i0_po0 dst:i4_pi1
# Processing: Channel net2: Single :src:i12_po0 dst:i1_pi0
# Processing: Channel net3: Single :src:i1_po0 dst:i5_pi1
# Processing: Channel net4: Single :src:i13_po0 dst:i2_pi0
# Processing: Channel net5: Single :src:i2_po0 dst:i6_pi1
# Processing: Channel net6: Single :src:i14_po0 dst:i3_pi0
# Processing: Channel net7: Single :src:i3_po0 dst:i7_pi1
# Processing: Channel net8: Single :src:i10_po0 dst:i8_pi0
# Processing: Channel net9: Single :src:i8_po0 dst:{broadcast i4_pi0 i5_pi0 i6_pi0 i7_pi0 }
# Processing: Channel net13: Single :src:i4_po0 dst:i5_pi2
# Processing: Channel net14: Single :src:i5_po0 dst:i6_pi2
# Processing: Channel net15: Single :src:i6_po0 dst:i7_pi2
# Processing: Channel net16: Single :src:i7_po0 dst:i9_pi0
# Processing: Channel net17: Single :src:i9_po0 dst:i15_pi0
# ### Channel processing Done. ####
# INFO: [aiecompiler 77-600] Emitting x86Sim Code
# INFO: [aiecompiler 77-608] New x86Sim Code Generation Complete
# INFO: [aiecompiler 77-599] Building simulation executable
# INFO: [aiecompiler 77-404] Executing Cmd: make -j4 -C /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/pthread -f makefile -O --no-print-directory all
# debug=no
# debug_lib_x86sim=no
# address_sanitizer=no
# clang_static_analyzer=no
# In file included from <built-in>:1:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/aieNative.h:8:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/aie_core.h:85:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/me_native.h:87:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_iss_types.h:16:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/chess.h:18:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit.h:16:
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:36: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |                                    ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:37: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:37: note: function parameter 'v' with unknown value cannot be used in a constant expression
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1091:46: note: declared here
#  1091 |     void unsignedMultiply(const VBitWrapper& v)
#       |                                              ^
# 3 warnings generated.
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/bin/aie_clang++ -S -emit-llvm -fPIC -c -o wrap_conv2d_w5C.cpp.ll -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5 -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init -D__AIENGINE__ -D__AIE_ARCH__=20 -std=c++2a -stdlib=libc++ -gdwarf-4 \
# -MT wrap_conv2d_w5C.cpp.ll -MMD -MP -MF wrap_conv2d_w5C.cpp.Td   wrap_conv2d_w5C.cpp
# In file included from <built-in>:1:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/aieNative.h:8:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/aie_core.h:85:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/me_native.h:87:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_iss_types.h:16:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/chess.h:18:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit.h:16:
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:36: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |                                    ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:37: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:37: note: function parameter 'v' with unknown value cannot be used in a constant expression
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1091:46: note: declared here
#  1091 |     void unsignedMultiply(const VBitWrapper& v)
#       |                                              ^
# 3 warnings generated.
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/bin/aie_clang++ -S -emit-llvm -fPIC -c -o wrap_conv2d_w5A.cpp.ll -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5 -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init -D__AIENGINE__ -D__AIE_ARCH__=20 -std=c++2a -stdlib=libc++ -gdwarf-4 \
# -MT wrap_conv2d_w5A.cpp.ll -MMD -MP -MF wrap_conv2d_w5A.cpp.Td   wrap_conv2d_w5A.cpp
# In file included from <built-in>:1:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/aieNative.h:8:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/aie_core.h:85:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/me_native.h:87:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_iss_types.h:16:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/chess.h:18:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit.h:16:
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:36: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |                                    ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:37: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:37: note: function parameter 'v' with unknown value cannot be used in a constant expression
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1091:46: note: declared here
#  1091 |     void unsignedMultiply(const VBitWrapper& v)
#       |                                              ^
# 3 warnings generated.
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/bin/aie_clang++ -S -emit-llvm -fPIC -c -o wrap_conv2d_w5B.cpp.ll -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5 -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init -D__AIENGINE__ -D__AIE_ARCH__=20 -std=c++2a -stdlib=libc++ -gdwarf-4 \
# -MT wrap_conv2d_w5B.cpp.ll -MMD -MP -MF wrap_conv2d_w5B.cpp.Td   wrap_conv2d_w5B.cpp
# In file included from <built-in>:1:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/aieNative.h:8:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/aie_core.h:85:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/me_native.h:87:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_iss_types.h:16:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/chess.h:18:
# In file included from /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit.h:16:
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:36: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |                                    ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:37: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:37: note: function parameter 'v' with unknown value cannot be used in a constant expression
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1091:46: note: declared here
#  1091 |     void unsignedMultiply(const VBitWrapper& v)
#       |                                              ^
# 3 warnings generated.
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/bin/aie_clang++ -S -emit-llvm -fPIC -c -o wrap_wts_init.cpp.ll -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5 -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init -D__AIENGINE__ -D__AIE_ARCH__=20 -std=c++2a -stdlib=libc++ -gdwarf-4 \
# -MT wrap_wts_init.cpp.ll -MMD -MP -MF wrap_wts_init.cpp.Td   wrap_wts_init.cpp
# /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/lnx64.o/tools/clang/bin/clang -S -emit-llvm -fPIC -E -MT -M -MM -MP -MF wrap_conv2d_w5_app.cpp.d -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5 -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init -I/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include -I/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/gcc/include/c++/8.3.0 -I/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/gcc/include/c++/8.3.0/x86_64-pc-linux-gnu -I/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/lnx64/gcc/include  -Wno-error=reserved-user-defined-literal  -std=c++17 -gdwarf-4 wrap_conv2d_w5_app.cpp
# g++ -fPIC -c -o PthreadSimBasic.cpp.o -MT PthreadSimBasic.cpp.o -MMD -MP -MF PthreadSimBasic.cpp.Td -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5 -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init -std=c++17 PthreadSimBasic.cpp
# g++ -fPIC -c -o PthreadSimXmc.cpp.o -MT PthreadSimXmc.cpp.o -MMD -MP -MF PthreadSimXmc.cpp.Td -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5 -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init -std=c++17 PthreadSimXmc.cpp
# set -o pipefail; \
# export XILINX_VITIS_AIETOOLS_X86SIM_OPT_OPTIONS="--thread-local-globals=1 --align-globals=1 --internalize-global-vars=1 --internalize-funcs=1 --truncate-vector-load-store-addresses=1 --max-required-vector-alignment=32"; /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/lnx64.o/tools/clang/bin/opt -S -load-pass-plugin=/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/lib/lnx64.o/libLLVMX86SimOpt.so -passes=x86simopt wrap_wts_init.cpp.ll -o wrap_wts_init.cpp.opt.ll 2>&1 | tee wrap_wts_init.cpp.opt.ll.log
# Failed to open log file : No such file or directory
# Add module pass X86SimThreadLocalGlobalsPass
# Add module pass X86SimExternalToInternalLinkagePass
# Add module pass X86SimExternalToInternalFunPass
# Add module pass X86SimAlignGlobalsPass
# Add module pass X86SimTruncVecLdStAddrPass
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v32int4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:733
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v64int4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:734
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v128int4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:735
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v256int4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:736
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v32uint4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:748
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v64uint4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:749
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v128uint4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:750
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v256uint4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:751
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v16int8' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:762
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v32int8' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:763
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v64int8' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:764
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v128int8' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:765
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v16uint8' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:776
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v32uint8' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:777
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v64uint8' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:778
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v128uint8' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:779
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v8int16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:789
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v16int16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:790
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v32int16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:791
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v64int16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:792
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v8uint16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:802
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v16uint16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:803
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v32uint16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:804
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v64uint16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:805
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v4int32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:814
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v8int32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:815
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v16int32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:816
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v32int32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:817
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v4uint32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:823
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v8uint32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:824
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v16uint32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:825
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v32uint32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:826
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v4cint16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:832
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v8cint16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:833
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v16cint16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:834
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v32cint16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:835
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v2cint32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:840
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v4cint32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:841
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v8cint32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:842
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v16cint32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:843
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK10v8bfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:848
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK11v16bfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:849
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK11v32bfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:850
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK11v64bfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:851
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK11v4cbfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:860
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK11v8cbfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:861
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK12v16cbfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:862
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v4float' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:864
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v8float' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:865
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v16float' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:866
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v32float' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:867
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v2cfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:869
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v4cfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:870
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v8cfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:871
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v16cfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:872
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK10v8accfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:875
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK11v16accfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:876
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK11v32accfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:877
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK11v4caccfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:879
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK11v8caccfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:880
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK12v16caccfloat' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:881
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v8acc32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:883
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v16acc32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:884
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v32acc32' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:885
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v4acc64' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:887
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v8acc64' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:888
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v16acc64' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:889
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v2cacc64' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:891
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v4cacc64' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:892
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v8cacc64' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:893
# Truncated the LSBs from the address of 15 'MemCpyInst' instructions in function '_ZN8wts_initI8bfloat16Lj18464EE3runEP12input_streamIS0_ERN3adf9io_bufferIS0_NS5_9direction3outENS5_16io_buffer_configINS5_7extentsIJLj4294967295EEEENS5_7locking5asyncENS5_10addressing6linearENS5_6marginILj0EEEEEEE' at /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/../wts_init/wts_init.cpp:30
# Truncated the LSBs from the address of 2 'MemCpyInst' instructions in function '_Z6insert11v16bfloat16i10v8bfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_chess_opns.h:8954
# Truncated the LSBs from the address of 2 'MemCpyInst' instructions in function '_Z19extract_v16bfloat1611v32bfloat16i' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_chess_opns.h:5877
# Truncated the LSBs from the address of 3 'MemCpyInst' instructions in function '_Z6insert11v32bfloat16i10v8bfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_chess_opns.h:8780
# Truncated the LSBs from the address of 2 'MemCpyInst' instructions in function '_Z15set_v32bfloat16i11v16bfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_chess_opns.h:5893
# Truncated the LSBs from the address of 2 'MemCpyInst' instructions in function '_Z15set_v32bfloat16i10v8bfloat16' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_chess_opns.h:8130
# Truncated the LSBs from the address of 2 'MemCpyInst' instructions in function '_Z3sel8v16int32S_j' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/data/aie_ml/lib/isg/me_chess_opns.h:5542
# truncate-vector-load-store-addresses: Truncated the LSBs from the address of 98 'MemCpyInst' instructions
# See /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/vfs_work/conv2d_w5_app_c8052cf7/Work/pthread/ for details.
# set -o pipefail; \
# export XILINX_VITIS_AIETOOLS_X86SIM_OPT_OPTIONS="--thread-local-globals=1 --align-globals=1 --internalize-global-vars=1 --internalize-funcs=1 --truncate-vector-load-store-addresses=1 --max-required-vector-alignment=32"; /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/lnx64.o/tools/clang/bin/opt -S -load-pass-plugin=/proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/lib/lnx64.o/libLLVMX86SimOpt.so -passes=x86simopt wrap_conv2d_w5A.cpp.ll -o wrap_conv2d_w5A.cpp.opt.ll 2>&1 | tee wrap_conv2d_w5A.cpp.opt.ll.log
# Failed to open log file : No such file or directory
# Add module pass X86SimThreadLocalGlobalsPass
# Add module pass X86SimExternalToInternalLinkagePass
# Add module pass X86SimExternalToInternalFunPass
# Add module pass X86SimAlignGlobalsPass
# Add module pass X86SimTruncVecLdStAddrPass
# Changed external linkage to internal linkage for '_ZN10conv2d_w5AC2Ev' at /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/conv2d_w5A.cpp:17
# Changed external linkage to internal linkage for '_ZN10conv2d_w5A8grab_wtsERN3adf9io_bufferI8bfloat16NS0_9direction2inENS0_16io_buffer_configINS0_7extentsIJLj4294967295EEEENS0_7locking5asyncENS0_10addressing6linearENS0_6marginILj0EEEEEEE' at /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/conv2d_w5A.cpp:28
# Changed external linkage to internal linkage for '_ZN10conv2d_w5A3runERN3adf9io_bufferI8bfloat16NS0_9direction2inENS0_16io_buffer_configINS0_7extentsIJLj4294967295EEEENS0_7locking4syncENS0_10addressing6linearENS0_6marginILj0EEEEEEERNS1_IS2_S4_NS5_IS7_NS8_5asyncESB_SD_EEEEP13output_streamIS2_E' at /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w5/conv2d_w5A.cpp:132
# internalize-funcs: Changed external linkage to internal linkage for 3 functions
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v32int4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:733
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v64int4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:734
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v128int4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:735
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v256int4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:736
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v32uint4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:748
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK8v64uint4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:749
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v128uint4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:750
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK9v256uint4' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:751
# Truncated the LSBs from the address of 1 'MemCpyInst' instruction in function '_Z11x86simPrintRK7v16int8' at //proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/aietools/include/adf/x86sim/streamApi.h:762
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 conv2d_w5_graph = vfs.aieGraph(
#       2     input_file='conv2d_w5_app.cpp',
#       3     part="xcve2802-vsvh1760-2MP-e-S",
#       4     include_paths=['./','../mnist','../wts_init'])
#       5 act_o = conv2d_w5_graph.run(va.array(ifm_i[:,0],va.bfloat16),
#       6                             va.array(wts_0_i[:,0],va.bfloat16),
#       7                             va.array(wts_1_i[:,0],va.bfloat16),
#       8                             va.array(wts_2_i[:,0],va.bfloat16),
#       9                             va.array(wts_3_i[:,0],va.bfloat16))
#
# File /proj/xbuilds/SWIP/9999.0_0309_1750/installs/lin64/Vitis/2025.1/functional_suite/vfs/python/vfs/aieGraph.py:56, in aieGraph.__init__(self, input_file, include_paths, part, platform, vfs_build_dir, config_file)
#      53     in_keys[i] = keys
#      54     in_values[i] = values
# ---> 56 self.component = vb.AieGraph(in_keys,in_values)
#      57 super().__init__()
#
# KeyboardInterrupt:

# %%
act_o = np.array(act_o)
print(act_o.shape)
act_o = np.reshape(act_o,(4,3,8,128))
ofm_o = np.reshape(ofm_o,(4,3,3,128))
act_o = act_o[:,:,:3,:]   # Remove zero pad
err = np.reshape(ofm_o-act_o,(-1,1))
tmp = np.reshape(ofm_o,(-1,1))
lvl = np.max(np.abs(tmp))
lvl_min = -(0.5**8)*lvl*np.ones((len(tmp),1))
lvl_max = +(0.5**8)*lvl*np.ones((len(tmp),1))
tt = np.arange(0,len(tmp))
plt.plot(tt,err,tt,lvl_min,tt,lvl_max)
plt.title("Pixel Error")
plt.show()

# %%
fig,ax = plt.subplots(nrows=2,ncols=2)
for ii in range(2):
    ax[ii,0].set(title="Model")
    ax[ii,1].set(title="AIE")
    ax[ii,0].imshow(ofm_o[0,:,:,ii].astype("float32"),cmap=plt.cm.binary)
    ax[ii,1].imshow(act_o[0,:,:,ii].astype("float32"),cmap=plt.cm.binary)

# %% [markdown]
# ## Regression Test for AIEsim

# %%
if os.path.exists('aiesimulator_output/data/ofm_o.txt'):
    with open('aiesimulator_output/data/ofm_o.txt','r') as file:
        lines = file.readlines()
        keep = [line for line in lines if not re.match(r'^T',line)]
        keep = [s.strip() for s in keep]
        keep = np.array([list(map(float,s.split())) for s in keep])
        ofm_aie = np.concatenate(keep)
        ofm_aie = np.reshape(ofm_aie,(4,5,8,64))
        ofm_aie = ofm_aie[:,:,:5,:]  # Remove zero pad
        err = np.reshape(act_o-ofm_aie,(-1,1))
        tmp = np.reshape(act_o,(-1,1))
        lvl = np.max(np.abs(tmp))
        lvl_min = -(0.5**8)*lvl*np.ones((len(tmp),1))
        lvl_max = +(0.5**8)*lvl*np.ones((len(tmp),1))
        tt = np.arange(0,len(tmp))
        plt.plot(tt,err,tt,lvl_min,tt,lvl_max)
        plt.title("X86 vs AIEsim Mismatch")
        plt.show()
