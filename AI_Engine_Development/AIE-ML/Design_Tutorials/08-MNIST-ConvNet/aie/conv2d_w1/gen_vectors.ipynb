# %% [markdown]
# # Testbench for `conv2d_w1()`

# %%
#
# Copyright (C) 2024, Advanced Micro Devices, Inc. All rights reserved.
# SPDX-License-Identifier: MIT
#
# Author: Mark Rollins

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from tensorflow.keras import mixed_precision
import numpy as np
import os.path
import os as os
import vfs
import varray as va
import re
# Out:
# 2025-05-07 09:08:36.672749: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-07 09:08:36.678937: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-07 09:08:36.690399: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746630516.706366 2053000 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746630516.711006 2053000 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-07 09:08:36.732745: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Layer Definition

# %%
inputs = keras.Input(shape=(28,28,1),name="input_layer")
outputs = layers.Conv2D(filters=16,kernel_size=3,activation="relu",name="conv2d_w1")(inputs)
model = keras.Model(inputs=inputs,outputs=outputs)
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
w_taps = np.loadtxt('taps_trained.txt')
w_taps = (w_taps.astype("bfloat16")).astype("float32")
w_bias = np.loadtxt('bias_trained.txt')
w_bias = (w_bias.astype("bfloat16")).astype("float32")
w_taps = np.reshape(w_taps,(3,3,1,16))
model.set_weights((w_taps,w_bias))
# Out:
# 2025-05-07 09:08:40.683302: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_w1 (Conv2D)              │ (None, 26, 26, 16)     │           160 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160 (640.00 B)
#  Trainable params: 160 (640.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Load NMIST Images

# %%
# Set batch size and # of batches
BS=1
NB_trn = 4
NB_tst = 4
# Load MNIST database:
(trn_images,trn_labels), (tst_images,tst_labels) = mnist.load_data()
tst_images = tst_images.reshape((10000,28,28,1))
tst_images = tst_images[:NB_tst*BS,:,:,:]
# Extract usable data:
tst_labels = tst_labels[:NB_tst*BS]
tst_images = tst_images.astype("float32") / 255
tst_images = (tst_images.astype("bfloat16")).astype("float32")

# %% [markdown]
# ## Compute Golden Outputs

# %%
predict = model.predict(tst_images,batch_size=1)
predict = (predict.astype("bfloat16")).astype("float32")
fig,ax = plt.subplots(nrows=1,ncols=1)
ax.imshow(tst_images[0],cmap=plt.cm.binary)
fig,ax = plt.subplots(nrows=4,ncols=4)
for ii in range(4):
    for jj in range(4):
        ax[ii,jj].imshow(predict[0,:,:,4*ii+jj],cmap=plt.cm.binary)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## Store Layer Inputs

# %%
os.makedirs('data',exist_ok=True)
np.savetxt('data/ifm_i.txt',np.reshape(tst_images,(-1,4)),fmt='%f %f %f %f')
ifm_i = np.reshape(tst_images,(-1,1))

# %% [markdown]
# ## Store Layer Outputs

# %%
np.savetxt('data/ofm_i.txt',np.reshape(predict,(-1,4)),fmt='%f %f %f %f')
ofm_o = np.reshape(predict,(-1,1))

# %% [markdown]
# ## Store Taps & Bias in 3x3 Column-Major Order to PLIO

# %%
tmp = np.concatenate((np.reshape(w_taps,(-1,1)),np.reshape(w_bias,(-1,1))),axis=0)
np.savetxt('data/wts_i.txt',np.reshape(tmp,(-1,4)),fmt='%f %f %f %f')
wts_i = np.reshape(tmp,(-1,1))

# %% [markdown]
# ## Run Vitis Functional Simulation

# %%
conv2d_w1_graph = vfs.aieGraph(
    input_file='conv2d_w1_app.cpp',
    part="xcve2802-vsvh1760-2MP-e-S",
    include_paths=['./','../mnist','../wts_init'])
act_o = conv2d_w1_graph.run(va.array(ifm_i[:,0],va.bfloat16),va.array(wts_i[:,0],va.bfloat16))
# Out:
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/bin/v++
# Compiling AIE Graph
# Compilation directory: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f
# Compilation command: v++ -c --mode aie --config vfs_work/conv2d_w1_app_5a0c682f/conv2d_w1_app.cfg --work_dir vfs_work/conv2d_w1_app_5a0c682f/Work --output vfs_work/conv2d_w1_app_5a0c682f/libadf.a --target x86sim
#
#
# ****** v++ v2025.1 (64-bit)
#   **** SW Build 6127654 on 2025-05-06-09:01:25
#   **** Start of session at: Wed May  7 09:08:43 2025
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#     ** Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
#
# INFO: [v++ 60-1548] Creating build summary session with primary output /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/Work.aiecompiler_summary, at Wed May  7 09:08:46 2025
# INFO: [v++ 82-31] Launching aiecompiler: aiecompiler --config /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/aie_x86sim.cfg
#                                            AI Engine Compiler
#                                      Version 2025.1 (linux64-bit)
#                                      SW Build 6127766 on 2025-05-06-09:54:53
#                           Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#                           Copyright 2022-2025 Advanced Micro Devices, Inc. All Rights Reserved.
# INFO: ML part stats configuration file found in /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data
# INFO: [aiecompiler 77-297] Cmd Line : /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/bin/unwrapped/lnx64.o/aiecompiler --config /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/aie_x86sim.cfg
# INFO: [aiecompiler 77-404] Executing Cmd: /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/bin/../lnx64.o/tools/clang/bin/clang++ -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/include/c++/8.3.0 -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/include/c++/8.3.0/x86_64-pc-linux-gnu -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/include  -Wno-error=reserved-user-defined-literal  -E -std=c++17 -D__ADF_FRONTEND__ -D__AIE_ARCH__=20 -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include  -I .  -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/conv2d_w1_app.cpp > /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app.ii
# INFO: [aiecompiler 77-404] Executing Cmd: graph_preprocessor /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app.ii -o /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app.processed.ii -report-core-dump  -- -std=c++17  -ftemplate-depth=2048  -Wno-return-stack-address  -Wno-missing-declarations  -Wno-parentheses-equality  -Wno-shift-negative-value
# INFO: [aiecompiler 77-404] Executing Cmd: /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/bin/../lnx64.o/tools/clang/bin/clang++ --ld-path=/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/binutils-2.42/bin/ld --gcc-install-dir=/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/lib/gcc/x86_64-pc-linux-gnu/8.3.0 -stdlib=libstdc++  -Wno-error=reserved-user-defined-literal  -std=c++17  -I .  /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app.processed.ii -o /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app.out -L /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lib/lnx64.o -g -O0 -Wl,--unresolved-symbols=ignore-all  -Wno-return-stack-address  -Wno-missing-declarations  -lmeir_frontend  -ladf_api_frontend
# INFO: [aiecompiler 77-404] Executing Cmd: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app.out -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init --workdir=/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work --part=xcve2802-vsvh1760-2MP-e-S --aiearch=aie-ml --log-level=1 --pl-axi-lite=0 --enable-multi-layer=0 --multi-layer-opt=0 --disable-dma-autostart=0 --enable-light-cdo=0 --large-program-memory=0 --swfifo-threshold=40 --enable-dma-fifo=1 --target=x86sim
# INFO: [aiecompiler 77-749] Reading logical device VC2802.json
# INFO: [aiecompiler 77-6447] Executing Cmd: aieir_be --time-passes=0  --workdir=/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work  --target=x86sim --include="/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./" --include="/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist" --include="/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init" --output-archive=vfs_work/conv2d_w1_app_5a0c682f/libadf.a  --event-trace-port=gmio --part=xcve2802-vsvh1760-2MP-e-S  --json="/group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app.json"
# INFO: [aiecompiler 77-749] Reading logical device VC2802.json
# 674: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app.json
# INFO: [aiecompiler 77-757] Opening input file: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app.json
# INFO: [aiecompiler 77-6287] Emitting AIEIr in file: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/conv2d_w1_app_aieir_dump.txt
# INFO: [aiecompiler 77-656] Processing Graph 'root'
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.MT is 1.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.kk is 4.
# INFO: [aiecompiler 77-5917] Repetition count for aie_dut.dut.weights.kk is 4.
# INFO: [aiecompiler 77-5607] ### Entering X86Sim Switch Configuration pass
# INFO: [aiecompiler 77-5606] ### Done with X86Sim Switch Configuration pass
# DEBUG:Buildx86simCFGraph:### Entering Build CFGraph pass
# DEBUG:Buildx86simCFGraph:### CF Graph is built
# INFO: [aiecompiler 77-610] Performing x86Sim Graph Analysis
# Start processing Node Instances.
# Processing Node Instance: me  i0:b0 runtime:0.8999 {
#    portinst: i0_pi0 idx[0] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  kk.in[0])
#    portinst: i0_po0 idx[1] datatype:buff<bfloat16> mem out bw_utlization = 1 synctype:async (variable name:  kk.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: me  i1:b1 runtime:0.8999 {
#    portinst: i1_pi0 idx[0] datatype:buff<bfloat16> mem in bw_utlization = 1 (variable name:  kk.in[0])
#    portinst: i1_pi1 idx[1] datatype:buff<bfloat16> mem in bw_utlization = 1 synctype:async (variable name:  kk.in[1])
#    portinst: i1_po0 idx[2] datatype:buff<bfloat16> mem out bw_utlization = 1 (variable name:  kk.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: SharedBuffer  i2:b2 { dimensions: (3136 ) elemType:bfloat16 numBuffers:1
#    portinst: i2_pi0 idx[0] datatype:bfloat16 dma in bw_utlization = 1 (variable name:  MT.in[0])
#    portinst: i2_po0 idx[1] datatype:bfloat16 dma out bw_utlization = 1 (variable name:  MT.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: plio  nodeinst:i3:b3 {
#    portinst: i3_po0 idx[-1] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  ifm_i.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: plio  nodeinst:i4:b4 {
#    portinst: i4_po0 idx[-1] datatype:strm<bfloat16> stream out bw_utlization = 1 (variable name:  wts_i.out[0])
# }
# Node Instance processing done.
# Processing Node Instance: plio  nodeinst:i5:b5 {
#    portinst: i5_pi0 idx[-1] datatype:strm<bfloat16> stream in bw_utlization = 1 (variable name:  ofm_o.in[0])
# }
# Node Instance processing done.
# Finished processing Node Instances.
# Processing: Channel net0: Single :src:i4_po0 dst:i0_pi0
# Processing: Channel net1: Single :src:i0_po0 dst:i1_pi1
# Processing: Channel net2: Single :src:i3_po0 dst:i2_pi0
# Processing: Channel net3: Single :src:i2_po0 dst:i1_pi0
# Processing: Channel net4: Single :src:i1_po0 dst:i5_pi0
# ### Channel processing Done. ####
# INFO: [aiecompiler 77-600] Emitting x86Sim Code
# INFO: [aiecompiler 77-608] New x86Sim Code Generation Complete
# INFO: [aiecompiler 77-599] Building simulation executable
# INFO: [aiecompiler 77-404] Executing Cmd: make -j4 -C /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/pthread -f makefile -O --no-print-directory all
# debug=no
# debug_lib_x86sim=no
# address_sanitizer=no
# clang_static_analyzer=no
# g++ -fPIC -c -o PthreadSimBasic.cpp.o -MT PthreadSimBasic.cpp.o -MMD -MP -MF PthreadSimBasic.cpp.Td -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1 -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/runtime_cxx/libcxx-lite/include -std=c++17 PthreadSimBasic.cpp
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lnx64.o/tools/clang/bin/clang -S -emit-llvm -fPIC -E -MT -M -MM -MP -MF wrap_conv2d_w1_app.cpp.d -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1 -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/runtime_cxx/libcxx-lite/include -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/include/c++/8.3.0 -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/include/c++/8.3.0/x86_64-pc-linux-gnu -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/include  -Wno-error=reserved-user-defined-literal  -std=c++17 -gdwarf-4 wrap_conv2d_w1_app.cpp
# g++ -fPIC -c -o PthreadSim.cpp.o -MT PthreadSim.cpp.o -MMD -MP -MF PthreadSim.cpp.Td -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1 -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/runtime_cxx/libcxx-lite/include -std=c++17 PthreadSim.cpp
# g++ -fPIC -c -o PthreadSimXmc.cpp.o -MT PthreadSimXmc.cpp.o -MMD -MP -MF PthreadSimXmc.cpp.Td -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1 -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/runtime_cxx/libcxx-lite/include -std=c++17 PthreadSimXmc.cpp
# g++ -fPIC -c -o PthreadSimSwemu.cpp.o -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/include -MT PthreadSimSwemu.cpp.o -MMD -MP -MF PthreadSimSwemu.cpp.Td -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1 -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/runtime_cxx/libcxx-lite/include -std=c++17 PthreadSimSwemu.cpp
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lnx64.o/tools/clang/bin/clang -S -emit-llvm -fPIC -c -o wrap_conv2d_w1_app.cpp.ll -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1 -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/runtime_cxx/libcxx-lite/include -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/include/c++/8.3.0 -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/include/c++/8.3.0/x86_64-pc-linux-gnu -I/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/include  -Wno-error=reserved-user-defined-literal  -std=c++17 -gdwarf-4 -MT wrap_conv2d_w1_app.cpp.ll -MMD -MP -MF wrap_conv2d_w1_app.cpp.Td  wrap_conv2d_w1_app.cpp
# set -o pipefail; \
# export XILINX_VITIS_AIETOOLS_X86SIM_OPT_OPTIONS="--thread-local-globals=0 --internalize-global-vars=0 --internalize-funcs=0 --align-globals=0 --max-required-vector-alignment=32 --define-undefined-luts=0 --define-kernel-stubs=1"; /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lnx64.o/tools/clang/bin/opt -S -load-pass-plugin=/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lib/lnx64.o/libLLVMX86SimOpt.so -passes=x86simopt --x86simopt-log wrap_conv2d_w1_app.cpp.opt.ll.log --verbose=0 wrap_conv2d_w1_app.cpp.ll -o wrap_conv2d_w1_app.cpp.opt.ll 2> >(tee -a wrap_conv2d_w1_app.cpp.opt.ll.log >&2)
# Add module pass X86SimKernelStubsPass
# define-kernel-stubs: Created empty definition for 2 functions
# See /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/pthread/wrap_conv2d_w1_app.cpp.opt.ll.log for details.
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lnx64.o/tools/clang/bin/clang -O1 -fpic -fvisibility=hidden -c -o wrap_conv2d_w1_app.cpp.o  wrap_conv2d_w1_app.cpp.opt.ll
# In file included from <built-in>:1:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include/adf/x86sim/aieNative.h:8:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/aie_core.h:85:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/me_native.h:87:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/isg/me_iss_types.h:16:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/chess.h:18:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit.h:16:
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:36: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |                                    ^
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:37: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:37: note: function parameter 'v' with unknown value cannot be used in a constant expression
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1091:46: note: declared here
#  1091 |     void unsignedMultiply(const VBitWrapper& v)
#       |                                              ^
# 3 warnings generated.
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/bin/aie_clang++ -S -emit-llvm -fPIC -c -o wrap_conv2d_w1.cpp.ll -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1 -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/runtime_cxx/libcxx-lite/include -D_X86SIM_LIBCPP_16 -D__AIENGINE__ -D__AIE_ARCH__=20 -std=c++2a -stdlib=libc++ -gdwarf-4 \
# -MT wrap_conv2d_w1.cpp.ll -MMD -MP -MF wrap_conv2d_w1.cpp.Td   wrap_conv2d_w1.cpp
# In file included from <built-in>:1:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include/adf/x86sim/aieNative.h:8:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/aie_core.h:85:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/me_native.h:87:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/isg/me_iss_types.h:16:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/chess.h:18:
# In file included from /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit.h:16:
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1098:36: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1098 |             chess_VLA(unsigned, w, wordCount * 2 * f);
#       |                                    ^
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1099:37: note: implicit use of 'this' pointer is only allowed within the evaluation of a call to a 'constexpr' member function
#  1099 |             chess_VLA(unsigned, v1, wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:13: warning: variable length arrays in C++ are a Clang extension [-Wvla-cxx-extension]
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |             ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vla.h:27:15: note: expanded from macro 'chess_VLA'
#    27 |     TYPE NAME[(NUM)]
#       |               ^~~~~
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1100:37: note: function parameter 'v' with unknown value cannot be used in a constant expression
#  1100 |             chess_VLA(unsigned, v2, v.wordCount * f);
#       |                                     ^
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/target_aie_ml/chessdir/vbit_wrapper.h:1091:46: note: declared here
#  1091 |     void unsignedMultiply(const VBitWrapper& v)
#       |                                              ^
# 3 warnings generated.
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/bin/aie_clang++ -S -emit-llvm -fPIC -c -o wrap_wts_init.cpp.ll -g  -D__X86SIM__ -D__PTHREAD_API__ -fvisibility=hidden -D__AIE_ARCH__=20  -D__LOCK_FENCE_MODE__=2 -DAIE_OPTION_SCALAR_FLOAT_ON_VECTOR -DAIE2_FP32_EMULATION_ACCURACY_FAST -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1 -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/osci_systemc/include -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/boost_1_72_0 -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/./ -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../mnist -I /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/../wts_init -I /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/data/aie_ml/lib/runtime_cxx/libcxx-lite/include -D_X86SIM_LIBCPP_16 -D__AIENGINE__ -D__AIE_ARCH__=20 -std=c++2a -stdlib=libc++ -gdwarf-4 \
# -MT wrap_wts_init.cpp.ll -MMD -MP -MF wrap_wts_init.cpp.Td   wrap_wts_init.cpp
# set -o pipefail; \
# export XILINX_VITIS_AIETOOLS_X86SIM_OPT_OPTIONS="--thread-local-globals=1 --align-globals=1 --internalize-global-vars=1 --internalize-funcs=1 --truncate-vector-load-store-addresses=1 --max-required-vector-alignment=32"; /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lnx64.o/tools/clang/bin/opt -S -load-pass-plugin=/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lib/lnx64.o/libLLVMX86SimOpt.so -passes=x86simopt --x86simopt-log wrap_conv2d_w1.cpp.opt.ll.log --verbose=0 wrap_conv2d_w1.cpp.ll -o wrap_conv2d_w1.cpp.opt.ll 2> >(tee -a wrap_conv2d_w1.cpp.opt.ll.log >&2)
# Add module pass X86SimThreadLocalGlobalsPass
# Add module pass X86SimExternalToInternalLinkagePass
# Add module pass X86SimExternalToInternalFunPass
# Add module pass X86SimAlignGlobalsPass
# Add module pass X86SimTruncVecLdStAddrPass
# internalize-funcs: Changed external linkage to internal linkage for 5 functions
# truncate-vector-load-store-addresses: Truncated the LSBs from the address of 341 'MemCpyInst' instructions
# See /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/pthread/wrap_conv2d_w1.cpp.opt.ll.log for details.
# set -o pipefail; \
# export XILINX_VITIS_AIETOOLS_X86SIM_OPT_OPTIONS="--thread-local-globals=1 --align-globals=1 --internalize-global-vars=1 --internalize-funcs=1 --truncate-vector-load-store-addresses=1 --max-required-vector-alignment=32"; /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lnx64.o/tools/clang/bin/opt -S -load-pass-plugin=/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lib/lnx64.o/libLLVMX86SimOpt.so -passes=x86simopt --x86simopt-log wrap_wts_init.cpp.opt.ll.log --verbose=0 wrap_wts_init.cpp.ll -o wrap_wts_init.cpp.opt.ll 2> >(tee -a wrap_wts_init.cpp.opt.ll.log >&2)
# Add module pass X86SimThreadLocalGlobalsPass
# Add module pass X86SimExternalToInternalLinkagePass
# Add module pass X86SimExternalToInternalFunPass
# Add module pass X86SimAlignGlobalsPass
# Add module pass X86SimTruncVecLdStAddrPass
# truncate-vector-load-store-addresses: Truncated the LSBs from the address of 98 'MemCpyInst' instructions
# See /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/pthread/wrap_wts_init.cpp.opt.ll.log for details.
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lnx64.o/tools/clang/bin/clang -fpic -fvisibility=hidden -c -o wrap_wts_init.cpp.o  wrap_wts_init.cpp.opt.ll
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lnx64.o/tools/clang/bin/clang -fpic -fvisibility=hidden -c -o wrap_conv2d_w1.cpp.o  wrap_conv2d_w1.cpp.opt.ll
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/bin/ld -o aie_kernels_obj.o -r wrap_wts_init.cpp.o wrap_conv2d_w1.cpp.o -L/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lib/lnx64.o -lc++ -lc++abi
# aie_g++ -shared -o libxmcsim.so -D__AIE_ARCH__=20 aie_kernels_obj.o  PthreadSimXmc.cpp.o PthreadSim.cpp.o -lc++ -lpthread -ladf_api_x86sim -lx86simDummySocketUtil -lx86simStreamApiAIE20 -lx86sim -Wl,-R/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lib/lnx64.o -Wl,-R/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/lib64
# aie_g++ -o sim.out -D__AIE_ARCH__=20 aie_kernels_obj.o  PthreadSimBasic.cpp.o PthreadSim.cpp.o wrap_conv2d_w1_app.cpp.o -lpthread -ladf_api_x86sim -lx86simSocketUtil -lx86simStreamApiAIE20 -lx86sim -Wl,-R/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lib/lnx64.o -Wl,-R/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/lib64
# aie_g++ -shared -o libsim.so -D__AIE_ARCH__=20 aie_kernels_obj.o  PthreadSimSwemu.cpp.o PthreadSim.cpp.o -lc++ -lpthread -ladf_api_x86sim -lx86simDummySocketUtil -lx86simStreamApiAIE20 -lx86sim -Wl,-R/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/lib/lnx64.o -Wl,-R/proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/lib64
# INFO: [aiecompiler 77-6228] ### Entering Packager pass
# INFO: [aiecompiler 77-4236] Adding hardware components under: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/hw.o
# INFO: [aiecompiler 77-4237] Adding software components under: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/sw.o
# INFO: [aiecompiler 77-4235] Adding emulation and config components under: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/temp/cfg.o
# INFO: [aiecompiler 77-1086] Generating hand-off archive: vfs_work/conv2d_w1_app_5a0c682f/libadf.a
# /proj/xbuilds/SWIP/2025.1_0506_1840/installs/lin64/2025.1/Vitis/aietools/tps/lnx64/gcc/bin/ar: creating vfs_work/conv2d_w1_app_5a0c682f/libadf.a
# INFO: [aiecompiler 77-6227] ### Done with Packager pass (0 secs)
# INFO: [aiecompiler 77-6439] Run completed. Find additional information in:
# 	Guidance: /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/reports/guidance.html
#
# INFO: [aiecompiler 77-6440] Use the vitis_analyzer tool to visualize and navigate the relevant reports. Run:
# 	vitis_analyzer /group/fndprod/mrollins/repos/forks/Vitis-Tutorials/AI_Engine_Development/AIE-ML/Design_Tutorials/08-MNIST-ConvNet/aie/conv2d_w1/vfs_work/conv2d_w1_app_5a0c682f/Work/conv2d_w1_app.aiecompile_summary
#
# Compilation Complete
# (WARNING:0, CRITICAL-WARNING:0, ERROR:0)
# INFO: [v++ 60-586] Created vfs_work/conv2d_w1_app_5a0c682f/libadf.a
# INFO: [v++ 60-791] Total elapsed time: 0h 0m 49s
# Loaded AIEGraph

# %%
act_o = np.array(act_o)
act_o = np.reshape(act_o,(4,26,32,16))
ofm_o = np.reshape(ofm_o,(4,26,26,16))
act_o = act_o[:,:,:26,:]   # Remove zero pad
err = np.reshape(ofm_o-act_o,(-1,1))
tmp = np.reshape(ofm_o,(-1,1))
lvl = np.max(np.abs(tmp))
lvl_min = -(0.5**8)*lvl*np.ones((len(tmp),1))
lvl_max = +(0.5**8)*lvl*np.ones((len(tmp),1))
tt = np.arange(0,len(tmp))
plt.plot(tt,err,tt,lvl_min,tt,lvl_max)
plt.title("Pixel Error")
plt.show()

# %%
print("Model    Actual")
fig,ax = plt.subplots(nrows=2,ncols=2)
for ii in range(2):
    ax[ii,0].set(title="Model")
    ax[ii,1].set(title="AIE")
    ax[ii,0].imshow(ofm_o[0,:,:,ii].astype("float32"),cmap=plt.cm.binary)
    ax[ii,1].imshow(act_o[0,:,:,ii].astype("float32"),cmap=plt.cm.binary,)
# Out:
# Model    Actual

# %% [markdown]
# ## Regression Test for AIEsim

# %%
if os.path.exists('aiesimulator_output/data/ofm_o.txt'):
    with open('aiesimulator_output/data/ofm_o.txt','r') as file:
        lines = file.readlines()
        keep = [line for line in lines if not re.match(r'^T',line)]
        keep = [s.strip() for s in keep]
        keep = np.array([list(map(float,s.split())) for s in keep])
        ofm_aie = np.concatenate(keep)
        ofm_aie = np.reshape(ofm_aie,(4,26,32,16))
        ofm_aie = ofm_aie[:,:,:26,:]  # Remove zero pad
        err = np.reshape(act_o-ofm_aie,(-1,1))
        tmp = np.reshape(act_o,(-1,1))
        lvl = np.max(np.abs(tmp))
        lvl_min = -(0.5**8)*lvl*np.ones((len(tmp),1))
        lvl_max = +(0.5**8)*lvl*np.ones((len(tmp),1))
        tt = np.arange(0,len(tmp))
        plt.plot(tt,err,tt,lvl_min,tt,lvl_max)
        plt.title("X86 vs AIEsim Mismatch")
        plt.show()
